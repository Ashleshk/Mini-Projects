# %% [markdown]
# ## Activation Function-Linear

# %% [markdown]
# **Import Library**

# %%
import os
import cv2
import random
import shutil
import numpy as np 
import pandas as pd 
import seaborn as sns
from tensorflow.keras.models import load_model
import matplotlib.pyplot as plt
from matplotlib.image import imread
from sklearn.metrics import confusion_matrix,classification_report
from tensorflow.keras.preprocessing.image import ImageDataGenerator,load_img
from tensorflow.keras.models import Sequential,Model
from tensorflow.keras.layers import Conv2D,Flatten,MaxPooling2D,Dense,GlobalAveragePooling2D,Dropout,BatchNormalization
from sklearn.model_selection import train_test_split
from tensorflow.keras.callbacks import ReduceLROnPlateau

# %% [markdown]
# #### Dataset Pre-processing

# %%
Y = []
path = "./Dataset/train"
filenames = os.listdir(path)
for img in os.listdir(path):
    val = img.split(".")[0]
    if val == "dog":
        Y.append('1')
    else:
        Y.append('0')

df = pd.DataFrame({
    'filename' : filenames,
    'category' : Y
})

# %%
df.head()
# Out:
#       filename category
# 0    cat.0.jpg        0
# 1    cat.1.jpg        0
# 2   cat.10.jpg        0
# 3  cat.100.jpg        0
# 4  cat.101.jpg        0

# %%
df.tail()
# Out:
#        filename category
# 395  dog.95.jpg        1
# 396  dog.96.jpg        1
# 397  dog.97.jpg        1
# 398  dog.98.jpg        1
# 399  dog.99.jpg        1

# %%
plt.figure(figsize=(12, 12))
for i in range(0, 9):
    plt.subplot(4, 3, i+1)
    sample = random.choice(filenames)
    filename = path+'/'+sample
    image = imread(filename)
    plt.imshow(image)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Model Training

# %%
train_df,val_df = train_test_split(df,test_size=0.2,random_state = 42)
train_df = train_df.reset_index(drop=True)
val_df = val_df.reset_index(drop=True)

# %%
train_df.shape
# Out:
# (320, 2)

# %%
val_df.shape
# Out:
# (80, 2)

# %%
train_df['category'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
val_df['category'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
batch_size = 32
epochs = 30
train_size = train_df.shape[0]
val_size = val_df.shape[0]
img_hieght = 128
img_width = 128
img_channels = 3

# %%
train_datagen = ImageDataGenerator(
    rescale = 1./255,
    rotation_range = 15,
    horizontal_flip = True,
    zoom_range = 0.2,
    shear_range = 0.1,
    fill_mode = 'reflect',
    width_shift_range = 0.1,
    height_shift_range = 0.1
)

train_generator = train_datagen.flow_from_dataframe(
    train_df,
    "./Dataset/train",
    x_col = 'filename',
    y_col = 'category',
    target_size = (img_hieght,img_width),
    batch_size = batch_size,
    class_mode = 'binary'
)
# Out:
# Found 320 validated image filenames belonging to 2 classes.

# %%
example_df = train_df.sample(n=1)
example_generator = train_datagen.flow_from_dataframe(
    example_df, 
    "./Dataset/train",
    x_col='filename',
    y_col='category',
    target_size=(img_hieght,img_width),
    class_mode='raw'
)
# Out:
# Found 1 validated image filenames.

# %%
plt.figure(figsize=(12, 12))
for i in range(0, 9):
    plt.subplot(4, 3, i+1)
    for X_batch, Y_batch in example_generator:
        image = X_batch[0]
        plt.imshow(image)
        break
plt.tight_layout()
plt.show()

# %%
val_datagen = ImageDataGenerator(
    rescale = 1./255,
)

val_generator = val_datagen.flow_from_dataframe(
    val_df,
    "./Dataset/train",
    x_col = 'filename',
    y_col = 'category',
    target_size = (img_hieght,img_width),
    batch_size = batch_size,
    class_mode = 'binary'
)
# Out:
# Found 80 validated image filenames belonging to 2 classes.

# %% [markdown]
# #### Model Compiling

# %%
model = Sequential()

model.add(Conv2D(32,(3,3),activation='relu',input_shape = (img_hieght,img_width,img_channels)))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))

model.add(Conv2D(64,(3,3),activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))

model.add(Conv2D(128,(3,3),activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))

model.add(Conv2D(256,(3,3),activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(512,activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.25))
model.add(Dense(1,activation='linear'))

# %%
learning_rate_reduction = ReduceLROnPlateau(monitor = 'val_accuracy',
                                            patience=2,
                                            factor=0.5,
                                            min_lr = 0.00001,
                                            verbose = 1)
callbacks = [learning_rate_reduction]

# %%
model.compile(optimizer='Adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
model.fit_generator(
    train_generator,
    epochs = epochs,
    validation_data =  val_generator,
    steps_per_epoch = train_size//batch_size,
    validation_steps = val_size//batch_size,
    callbacks = callbacks
)
# Out:
# Epoch 1/30
# C:\Users\supri\AppData\Local\Temp/ipykernel_11932/1255825298.py:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   model.fit_generator(
# 10/10 [==============================] - 6s 466ms/step - loss: 7.0991 - accuracy: 0.4969 - val_loss: 8.3394 - val_accuracy: 0.4531 - lr: 0.0010
# Epoch 2/30
# 10/10 [==============================] - 4s 425ms/step - loss: 6.1279 - accuracy: 0.5750 - val_loss: 9.0542 - val_accuracy: 0.4062 - lr: 0.0010
# Epoch 3/30
# 10/10 [==============================] - 10s 1s/step - loss: 6.7879 - accuracy: 0.5375 - val_loss: 6.0652 - val_accuracy: 0.5781 - lr: 0.0010
# Epoch 4/30
# 10/10 [==============================] - 10s 955ms/step - loss: 7.1543 - accuracy: 0.5250 - val_loss: 7.4687 - val_accuracy: 0.5156 - lr: 0.0010
# Epoch 5/30
# 10/10 [==============================] - ETA: 0s - loss: 6.1479 - accuracy: 0.5750
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 10/10 [==============================] - 8s 782ms/step - loss: 6.1479 - accuracy: 0.5750 - val_loss: 4.5642 - val_accuracy: 0.5156 - lr: 0.0010
# Epoch 6/30
# 10/10 [==============================] - 7s 713ms/step - loss: 6.8427 - accuracy: 0.5281 - val_loss: 5.5538 - val_accuracy: 0.4844 - lr: 5.0000e-04
# Epoch 7/30
# 10/10 [==============================] - ETA: 0s - loss: 7.2890 - accuracy: 0.5031
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 10/10 [==============================] - 8s 772ms/step - loss: 7.2890 - accuracy: 0.5031 - val_loss: 6.6049 - val_accuracy: 0.4688 - lr: 5.0000e-04
# Epoch 8/30
# 10/10 [==============================] - 9s 878ms/step - loss: 6.6432 - accuracy: 0.5531 - val_loss: 6.1325 - val_accuracy: 0.4844 - lr: 2.5000e-04
# Epoch 9/30
# 10/10 [==============================] - ETA: 0s - loss: 7.0262 - accuracy: 0.5094
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 10/10 [==============================] - 9s 855ms/step - loss: 7.0262 - accuracy: 0.5094 - val_loss: 6.5484 - val_accuracy: 0.5469 - lr: 2.5000e-04
# Epoch 10/30
# 10/10 [==============================] - 8s 764ms/step - loss: 6.6784 - accuracy: 0.5500 - val_loss: 7.2304 - val_accuracy: 0.5312 - lr: 1.2500e-04
# Epoch 11/30
# 10/10 [==============================] - ETA: 0s - loss: 6.7295 - accuracy: 0.5500
# Epoch 11: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 10/10 [==============================] - 9s 863ms/step - loss: 6.7295 - accuracy: 0.5500 - val_loss: 6.7484 - val_accuracy: 0.5625 - lr: 1.2500e-04
# Epoch 12/30
# 10/10 [==============================] - 8s 768ms/step - loss: 6.7609 - accuracy: 0.5437 - val_loss: 6.5074 - val_accuracy: 0.5781 - lr: 6.2500e-05
# Epoch 13/30
# 10/10 [==============================] - ETA: 0s - loss: 6.9713 - accuracy: 0.5344
# Epoch 13: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 10/10 [==============================] - 9s 861ms/step - loss: 6.9713 - accuracy: 0.5344 - val_loss: 8.1945 - val_accuracy: 0.4688 - lr: 6.2500e-05
# Epoch 14/30
# 10/10 [==============================] - 7s 738ms/step - loss: 7.0359 - accuracy: 0.5188 - val_loss: 7.4715 - val_accuracy: 0.5156 - lr: 3.1250e-05
# Epoch 15/30
# 10/10 [==============================] - 8s 765ms/step - loss: 6.8674 - accuracy: 0.5281 - val_loss: 6.2664 - val_accuracy: 0.5938 - lr: 3.1250e-05
# Epoch 16/30
# 10/10 [==============================] - 8s 758ms/step - loss: 6.8348 - accuracy: 0.5375 - val_loss: 6.9894 - val_accuracy: 0.5469 - lr: 3.1250e-05
# Epoch 17/30
# 10/10 [==============================] - ETA: 0s - loss: 6.4632 - accuracy: 0.5594
# Epoch 17: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 10/10 [==============================] - 8s 819ms/step - loss: 6.4632 - accuracy: 0.5594 - val_loss: 6.9894 - val_accuracy: 0.5469 - lr: 3.1250e-05
# Epoch 18/30
# 10/10 [==============================] - 8s 844ms/step - loss: 6.6316 - accuracy: 0.5625 - val_loss: 7.7125 - val_accuracy: 0.5000 - lr: 1.5625e-05
# Epoch 19/30
# 10/10 [==============================] - ETA: 0s - loss: 6.7839 - accuracy: 0.5344
# Epoch 19: ReduceLROnPlateau reducing learning rate to 1e-05.
# 10/10 [==============================] - 9s 896ms/step - loss: 6.7839 - accuracy: 0.5344 - val_loss: 6.2664 - val_accuracy: 0.5938 - lr: 1.5625e-05
# Epoch 20/30
# 10/10 [==============================] - 9s 843ms/step - loss: 7.4071 - accuracy: 0.5063 - val_loss: 7.2304 - val_accuracy: 0.5312 - lr: 1.0000e-05
# Epoch 21/30
# 10/10 [==============================] - 8s 792ms/step - loss: 6.6010 - accuracy: 0.5344 - val_loss: 6.9905 - val_accuracy: 0.5469 - lr: 1.0000e-05
# Epoch 22/30
# 10/10 [==============================] - 7s 742ms/step - loss: 6.4512 - accuracy: 0.5625 - val_loss: 6.7484 - val_accuracy: 0.5625 - lr: 1.0000e-05
# Epoch 23/30
# 10/10 [==============================] - 8s 769ms/step - loss: 6.4565 - accuracy: 0.5531 - val_loss: 7.7132 - val_accuracy: 0.5000 - lr: 1.0000e-05
# Epoch 24/30
# 10/10 [==============================] - 8s 764ms/step - loss: 6.9231 - accuracy: 0.5406 - val_loss: 6.7763 - val_accuracy: 0.5469 - lr: 1.0000e-05
# Epoch 25/30
# 10/10 [==============================] - 8s 796ms/step - loss: 7.1351 - accuracy: 0.5156 - val_loss: 7.2567 - val_accuracy: 0.5156 - lr: 1.0000e-05
# Epoch 26/30
# 10/10 [==============================] - 8s 766ms/step - loss: 6.6294 - accuracy: 0.5594 - val_loss: 7.9515 - val_accuracy: 0.4844 - lr: 1.0000e-05
# Epoch 27/30
# 10/10 [==============================] - 9s 905ms/step - loss: 7.0117 - accuracy: 0.5344 - val_loss: 6.7468 - val_accuracy: 0.5625 - lr: 1.0000e-05
# Epoch 28/30
# 10/10 [==============================] - 8s 792ms/step - loss: 6.6386 - accuracy: 0.5562 - val_loss: 7.0003 - val_accuracy: 0.5469 - lr: 1.0000e-05
# Epoch 29/30
# 10/10 [==============================] - 8s 808ms/step - loss: 6.6518 - accuracy: 0.5469 - val_loss: 7.2617 - val_accuracy: 0.5156 - lr: 1.0000e-05
# Epoch 30/30
# 10/10 [==============================] - 8s 817ms/step - loss: 6.5087 - accuracy: 0.5594 - val_loss: 7.8119 - val_accuracy: 0.4688 - lr: 1.0000e-05

# %% [markdown]
# #### Model Evaluation

# %%
score = model.evaluate_generator(val_generator)
print(score[1]*100)
# Out:
# C:\Users\supri\AppData\Local\Temp/ipykernel_11932/4056359736.py:1: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   score = model.evaluate_generator(val_generator)
# 50.0

# %%
score = model.evaluate_generator(train_generator)
print(score[1]*100)
# Out:
# C:\Users\supri\AppData\Local\Temp/ipykernel_11932/92563152.py:1: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   score = model.evaluate_generator(train_generator)
# 49.37500059604645

# %%
conf_datagen = ImageDataGenerator(
    rescale = 1./255,
)

conf_generator = conf_datagen.flow_from_dataframe(
    val_df,
    "./Dataset/train",
    x_col = 'filename',
    y_col = 'category',
    target_size = (img_hieght,img_width),
    batch_size = batch_size,
    shuffle = False,
    class_mode = 'binary'
)
# Out:
# Found 80 validated image filenames belonging to 2 classes.

# %%
y_predict = model.predict_generator(conf_generator)
# Out:
# C:\Users\supri\AppData\Local\Temp/ipykernel_11932/652915762.py:1: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   y_predict = model.predict_generator(conf_generator)

# %%
y_predict = np.where(y_predict > 0.5, 1, 0)

# %%
p = conf_generator.classes
q = y_predict
p = np.array(p)
q = q.flatten()

# %% [markdown]
# #### Confusion Matrix

# %%
cfm = confusion_matrix(p, q)
print(cfm)
ax= plt.subplot()
sns.heatmap(cfm, annot=True, ax = ax);
# labels, title and ticks
ax.set_xlabel('Predicted labels')
ax.set_ylabel('True labels');
ax.set_title('Confusion Matrix');
ax.xaxis.set_ticklabels(['cats', 'dogs'])
ax.yaxis.set_ticklabels(['cats', 'dogs'])
# Out:
# [[39  5]
#  [35  1]]
# [Text(0, 0.5, 'cats'), Text(0, 1.5, 'dogs')]

# %% [markdown]
# #### Classification Matrix

# %%
print(classification_report(p,q))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.53      0.89      0.66        44
#            1       0.17      0.03      0.05        36
#
#     accuracy                           0.50        80
#    macro avg       0.35      0.46      0.35        80
# weighted avg       0.36      0.50      0.38        80
