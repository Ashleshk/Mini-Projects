# %% [markdown]
# ## Activation Function-tanh

# %% [markdown]
# **Import Library**

# %%
import os
import cv2
import random
import shutil
import numpy as np 
import pandas as pd 
import seaborn as sns
from tensorflow.keras.models import load_model
import matplotlib.pyplot as plt
from matplotlib.image import imread
from sklearn.metrics import confusion_matrix,classification_report
from tensorflow.keras.preprocessing.image import ImageDataGenerator,load_img
from tensorflow.keras.models import Sequential,Model
from tensorflow.keras.layers import Conv2D,Flatten,MaxPooling2D,Dense,GlobalAveragePooling2D,Dropout,BatchNormalization
from sklearn.model_selection import train_test_split
from tensorflow.keras.callbacks import ReduceLROnPlateau

# %% [markdown]
# #### Dataset Pre-processing

# %%
Y = []
path = "./Dataset/train"
filenames = os.listdir(path)
for img in os.listdir(path):
    val = img.split(".")[0]
    if val == "dog":
        Y.append('1')
    else:
        Y.append('0')

df = pd.DataFrame({
    'filename' : filenames,
    'category' : Y
})

# %%
df.head()
# Out:
#       filename category
# 0    cat.0.jpg        0
# 1    cat.1.jpg        0
# 2   cat.10.jpg        0
# 3  cat.100.jpg        0
# 4  cat.101.jpg        0

# %%
df.tail()
# Out:
#        filename category
# 395  dog.95.jpg        1
# 396  dog.96.jpg        1
# 397  dog.97.jpg        1
# 398  dog.98.jpg        1
# 399  dog.99.jpg        1

# %%
plt.figure(figsize=(12, 12))
for i in range(0, 9):
    plt.subplot(4, 3, i+1)
    sample = random.choice(filenames)
    filename = path+'/'+sample
    image = imread(filename)
    plt.imshow(image)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Model Training

# %%
train_df,val_df = train_test_split(df,test_size=0.2,random_state = 42)
train_df = train_df.reset_index(drop=True)
val_df = val_df.reset_index(drop=True)

# %%
train_df.shape
# Out:
# (320, 2)

# %%
val_df.shape
# Out:
# (80, 2)

# %%
train_df['category'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
val_df['category'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
batch_size = 32
epochs = 30
train_size = train_df.shape[0]
val_size = val_df.shape[0]
img_hieght = 128
img_width = 128
img_channels = 3

# %%
train_datagen = ImageDataGenerator(
    rescale = 1./255,
    rotation_range = 15,
    horizontal_flip = True,
    zoom_range = 0.2,
    shear_range = 0.1,
    fill_mode = 'reflect',
    width_shift_range = 0.1,
    height_shift_range = 0.1
)

train_generator = train_datagen.flow_from_dataframe(
    train_df,
    "./Dataset/train",
    x_col = 'filename',
    y_col = 'category',
    target_size = (img_hieght,img_width),
    batch_size = batch_size,
    class_mode = 'binary'
)
# Out:
# Found 320 validated image filenames belonging to 2 classes.

# %%
example_df = train_df.sample(n=1)
example_generator = train_datagen.flow_from_dataframe(
    example_df, 
    "./Dataset/train",
    x_col='filename',
    y_col='category',
    target_size=(img_hieght,img_width),
    class_mode='raw'
)
# Out:
# Found 1 validated image filenames.

# %%
plt.figure(figsize=(12, 12))
for i in range(0, 9):
    plt.subplot(4, 3, i+1)
    for X_batch, Y_batch in example_generator:
        image = X_batch[0]
        plt.imshow(image)
        break
plt.tight_layout()
plt.show()

# %%
val_datagen = ImageDataGenerator(
    rescale = 1./255,
)

val_generator = val_datagen.flow_from_dataframe(
    val_df,
    "./Dataset/train",
    x_col = 'filename',
    y_col = 'category',
    target_size = (img_hieght,img_width),
    batch_size = batch_size,
    class_mode = 'binary'
)
# Out:
# Found 80 validated image filenames belonging to 2 classes.

# %% [markdown]
# #### Model Compiling

# %%
model = Sequential()

model.add(Conv2D(32,(3,3),activation='relu',input_shape = (img_hieght,img_width,img_channels)))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))

model.add(Conv2D(64,(3,3),activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))

model.add(Conv2D(128,(3,3),activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))

model.add(Conv2D(256,(3,3),activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(512,activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.25))
model.add(Dense(1,activation='tanh'))

# %%
learning_rate_reduction = ReduceLROnPlateau(monitor = 'val_accuracy',
                                            patience=2,
                                            factor=0.5,
                                            min_lr = 0.00001,
                                            verbose = 1)
callbacks = [learning_rate_reduction]

# %%
model.compile(optimizer='Adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
model.fit_generator(
    train_generator,
    epochs = epochs,
    validation_data =  val_generator,
    steps_per_epoch = train_size//batch_size,
    validation_steps = val_size//batch_size,
    callbacks = callbacks
)
# Out:
# C:\Users\supri\AppData\Local\Temp/ipykernel_22648/1255825298.py:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   model.fit_generator(
# Epoch 1/30
# 10/10 [==============================] - 11s 1s/step - loss: 5.3091 - accuracy: 0.5469 - val_loss: 6.1173 - val_accuracy: 0.4688 - lr: 0.0010
# Epoch 2/30
# 10/10 [==============================] - 11s 1s/step - loss: 5.3893 - accuracy: 0.5906 - val_loss: 7.2941 - val_accuracy: 0.4375 - lr: 0.0010
# Epoch 3/30
# 10/10 [==============================] - 10s 998ms/step - loss: 5.3088 - accuracy: 0.5844 - val_loss: 5.1026 - val_accuracy: 0.5000 - lr: 0.0010
# Epoch 4/30
# 10/10 [==============================] - 11s 1s/step - loss: 5.2806 - accuracy: 0.5844 - val_loss: 5.8698 - val_accuracy: 0.4531 - lr: 0.0010
# Epoch 5/30
# 10/10 [==============================] - ETA: 0s - loss: 5.0380 - accuracy: 0.6187
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 10/10 [==============================] - 11s 1s/step - loss: 5.0380 - accuracy: 0.6187 - val_loss: 4.6052 - val_accuracy: 0.4844 - lr: 0.0010
# Epoch 6/30
# 10/10 [==============================] - 10s 985ms/step - loss: 4.9601 - accuracy: 0.5938 - val_loss: 5.1962 - val_accuracy: 0.5156 - lr: 5.0000e-04
# Epoch 7/30
# 10/10 [==============================] - 10s 1s/step - loss: 4.4834 - accuracy: 0.6313 - val_loss: 7.0670 - val_accuracy: 0.5312 - lr: 5.0000e-04
# Epoch 8/30
# 10/10 [==============================] - 10s 1s/step - loss: 4.6601 - accuracy: 0.6250 - val_loss: 6.5074 - val_accuracy: 0.5781 - lr: 5.0000e-04
# Epoch 9/30
# 10/10 [==============================] - 11s 1s/step - loss: 4.2625 - accuracy: 0.6375 - val_loss: 6.5074 - val_accuracy: 0.5781 - lr: 5.0000e-04
# Epoch 10/30
# 10/10 [==============================] - ETA: 0s - loss: 4.3381 - accuracy: 0.6094
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 10/10 [==============================] - 10s 1s/step - loss: 4.3381 - accuracy: 0.6094 - val_loss: 7.7125 - val_accuracy: 0.5000 - lr: 5.0000e-04
# Epoch 11/30
# 10/10 [==============================] - 10s 1s/step - loss: 4.3938 - accuracy: 0.6125 - val_loss: 6.9894 - val_accuracy: 0.5469 - lr: 2.5000e-04
# Epoch 12/30
# 10/10 [==============================] - ETA: 0s - loss: 4.7496 - accuracy: 0.6219
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 10/10 [==============================] - 10s 985ms/step - loss: 4.7496 - accuracy: 0.6219 - val_loss: 6.7484 - val_accuracy: 0.5625 - lr: 2.5000e-04
# Epoch 13/30
# 10/10 [==============================] - 10s 1s/step - loss: 3.7774 - accuracy: 0.6781 - val_loss: 6.9894 - val_accuracy: 0.5469 - lr: 1.2500e-04
# Epoch 14/30
# 10/10 [==============================] - ETA: 0s - loss: 3.7377 - accuracy: 0.6844
# Epoch 14: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 10/10 [==============================] - 10s 1s/step - loss: 3.7377 - accuracy: 0.6844 - val_loss: 6.7484 - val_accuracy: 0.5625 - lr: 1.2500e-04
# Epoch 15/30
# 10/10 [==============================] - 10s 996ms/step - loss: 3.7266 - accuracy: 0.6844 - val_loss: 6.7484 - val_accuracy: 0.5625 - lr: 6.2500e-05
# Epoch 16/30
# 10/10 [==============================] - 11s 1s/step - loss: 3.9404 - accuracy: 0.6844 - val_loss: 6.2664 - val_accuracy: 0.5938 - lr: 6.2500e-05
# Epoch 17/30
# 10/10 [==============================] - 10s 1s/step - loss: 3.5705 - accuracy: 0.6969 - val_loss: 6.7484 - val_accuracy: 0.5625 - lr: 6.2500e-05
# Epoch 18/30
# 10/10 [==============================] - ETA: 0s - loss: 3.8373 - accuracy: 0.6750
# Epoch 18: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 10/10 [==============================] - 10s 1s/step - loss: 3.8373 - accuracy: 0.6750 - val_loss: 6.5074 - val_accuracy: 0.5781 - lr: 6.2500e-05
# Epoch 19/30
# 10/10 [==============================] - 10s 974ms/step - loss: 3.6856 - accuracy: 0.6687 - val_loss: 6.7484 - val_accuracy: 0.5625 - lr: 3.1250e-05
# Epoch 20/30
# 10/10 [==============================] - ETA: 0s - loss: 3.6999 - accuracy: 0.6750
# Epoch 20: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 10/10 [==============================] - 8s 788ms/step - loss: 3.6999 - accuracy: 0.6750 - val_loss: 6.5094 - val_accuracy: 0.5781 - lr: 3.1250e-05
# Epoch 21/30
# 10/10 [==============================] - 8s 798ms/step - loss: 3.6496 - accuracy: 0.6875 - val_loss: 7.4715 - val_accuracy: 0.5156 - lr: 1.5625e-05
# Epoch 22/30
# 10/10 [==============================] - ETA: 0s - loss: 4.0506 - accuracy: 0.6469
# Epoch 22: ReduceLROnPlateau reducing learning rate to 1e-05.
# 10/10 [==============================] - 8s 783ms/step - loss: 4.0506 - accuracy: 0.6469 - val_loss: 7.0212 - val_accuracy: 0.5312 - lr: 1.5625e-05
# Epoch 23/30
# 10/10 [==============================] - 8s 759ms/step - loss: 3.8246 - accuracy: 0.6625 - val_loss: 6.7960 - val_accuracy: 0.5469 - lr: 1.0000e-05
# Epoch 24/30
# 10/10 [==============================] - 7s 714ms/step - loss: 3.8832 - accuracy: 0.6562 - val_loss: 7.2304 - val_accuracy: 0.5312 - lr: 1.0000e-05
# Epoch 25/30
# 10/10 [==============================] - 8s 749ms/step - loss: 3.4364 - accuracy: 0.6875 - val_loss: 8.0261 - val_accuracy: 0.4688 - lr: 1.0000e-05
# Epoch 26/30
# 10/10 [==============================] - 7s 742ms/step - loss: 3.9349 - accuracy: 0.6719 - val_loss: 6.8361 - val_accuracy: 0.5469 - lr: 1.0000e-05
# Epoch 27/30
# 10/10 [==============================] - 10s 915ms/step - loss: 3.9063 - accuracy: 0.6656 - val_loss: 6.8562 - val_accuracy: 0.5469 - lr: 1.0000e-05
# Epoch 28/30
# 10/10 [==============================] - 8s 741ms/step - loss: 3.8366 - accuracy: 0.6531 - val_loss: 6.9894 - val_accuracy: 0.5469 - lr: 1.0000e-05
# Epoch 29/30
# 10/10 [==============================] - 8s 776ms/step - loss: 3.5988 - accuracy: 0.6719 - val_loss: 7.4715 - val_accuracy: 0.5156 - lr: 1.0000e-05
# Epoch 30/30
# 10/10 [==============================] - 7s 729ms/step - loss: 4.0356 - accuracy: 0.6344 - val_loss: 7.6939 - val_accuracy: 0.5000 - lr: 1.0000e-05

# %% [markdown]
# #### Model Evaluation

# %%
score = model.evaluate_generator(val_generator)
print(score[1]*100)
# Out:
# C:\Users\supri\AppData\Local\Temp/ipykernel_22648/4056359736.py:1: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   score = model.evaluate_generator(val_generator)
# 53.75000238418579

# %%
score = model.evaluate_generator(train_generator)
print(score[1]*100)
# Out:
# C:\Users\supri\AppData\Local\Temp/ipykernel_22648/92563152.py:1: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   score = model.evaluate_generator(train_generator)
# 49.06249940395355

# %%
conf_datagen = ImageDataGenerator(
    rescale = 1./255,
)

conf_generator = conf_datagen.flow_from_dataframe(
    val_df,
    "./Dataset/train",
    x_col = 'filename',
    y_col = 'category',
    target_size = (img_hieght,img_width),
    batch_size = batch_size,
    shuffle = False,
    class_mode = 'binary'
)
# Out:
# Found 80 validated image filenames belonging to 2 classes.

# %%
y_predict = model.predict_generator(conf_generator)
# Out:
# C:\Users\supri\AppData\Local\Temp/ipykernel_22648/652915762.py:1: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   y_predict = model.predict_generator(conf_generator)

# %%
y_predict = np.where(y_predict > 0.5, 1, 0)

# %%
p = conf_generator.classes
q = y_predict
p = np.array(p)
q = q.flatten()

# %% [markdown]
# #### Confusion Matrix

# %%
cfm = confusion_matrix(p, q)
print(cfm)
ax= plt.subplot()
sns.heatmap(cfm, annot=True, ax = ax);
# labels, title and ticks
ax.set_xlabel('Predicted labels')
ax.set_ylabel('True labels');
ax.set_title('Confusion Matrix');
ax.xaxis.set_ticklabels(['cats', 'dogs'])
ax.yaxis.set_ticklabels(['cats', 'dogs'])
# Out:
# [[43  1]
#  [36  0]]
# [Text(0, 0.5, 'cats'), Text(0, 1.5, 'dogs')]

# %% [markdown]
# #### Classification Matrix

# %%
print(classification_report(p,q))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.54      0.98      0.70        44
#            1       0.00      0.00      0.00        36
#
#     accuracy                           0.54        80
#    macro avg       0.27      0.49      0.35        80
# weighted avg       0.30      0.54      0.38        80
