# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import Imputer
import seaborn as sb
import matplotlib.pyplot as plt

# %%
df_train=pd.read_csv('train.csv')
df_test=pd.read_csv('test.csv')

# %%
cor=df_train.corr()

# %%
sb.distplot(df_train['SalePrice'])

# %%
target=np.log(df_train['SalePrice'])

# %%
sb.distplot(target)

# %%
num_data=df_train.select_dtypes(include=np.number)
cat_data=df_train.select_dtypes(exclude=np.number)
num_data.shape[1],cat_data.shape[1]
# Out:
# (38, 43)

# %%
del num_data['Id']

# %%
corr_num=num_data.corr()
sb.heatmap(corr_num)

# %%
sb.barplot(data=df_train,x='YrSold',y='MoSold')

# %%
"""f=pd.melt(df_train,value_vars=sorted(num_data))
g=sb.FacetGrid(f,col='variable',col_wrap=4,sharex=False,sharey=False)
g=g.map(sb.distplot,'value')"""
# Out:
# "f=pd.melt(df_train,value_vars=sorted(num_data))\ng=sb.FacetGrid(f,col='variable',col_wrap=4,sharex=False,sharey=False)\ng=g.map(sb.distplot,'value')"

# %%
"""f1=pd.melt(df_train,value_vars=sorted(cat_data))
g1=sb.FacetGrid(f1,col='variable',col_wrap=4,sharex=False,sharey=False)
plt.xticks(rotation='vertical')
g1=g1.map(sb.countplot,'value')
g1.fig.tight_layout()
plt.show()"""
# Out:
# "f1=pd.melt(df_train,value_vars=sorted(cat_data))\ng1=sb.FacetGrid(f1,col='variable',col_wrap=4,sharex=False,sharey=False)\nplt.xticks(rotation='vertical')\ng1=g1.map(sb.countplot,'value')\ng1.fig.tight_layout()\nplt.show()"

# %%
num_data.columns,cat_data.columns
# Out:
# (Index(['MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual', 'OverallCond',
#         'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2',
#         'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#         'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#         'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces',
#         'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF',
#         'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal',
#         'MoSold', 'YrSold', 'SalePrice'],
#        dtype='object'),
#  Index(['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities',
#         'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
#         'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st',
#         'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation',
# ...

# %%
miss=df_train.isnull().columns

# %%
df_train[miss]=df_train[miss].fillna(0)

# %%
df_train.isnull().sum().head(40)
# Out:
# Id              0
# MSSubClass      0
# MSZoning        0
# LotFrontage     0
# LotArea         0
# Street          0
# Alley           0
# LotShape        0
# LandContour     0
# Utilities       0
# LotConfig       0
# LandSlope       0
# Neighborhood    0
# Condition1      0
# Condition2      0
# BldgType        0
# HouseStyle      0
# OverallQual     0
# OverallCond     0
# YearBuilt       0
# YearRemodAdd    0
# RoofStyle       0
# RoofMatl        0
# Exterior1st     0
# Exterior2nd     0
# MasVnrType      0
# MasVnrArea      0
# ExterQual       0
# ExterCond       0
# Foundation      0
# BsmtQual        0
# BsmtCond        0
# BsmtExposure    0
# BsmtFinType1    0
# BsmtFinSF1      0
# BsmtFinType2    0
# BsmtFinSF2      0
# BsmtUnfSF       0
# TotalBsmtSF     0
# Heating         0
# dtype: int64

# %%
"""plt.figure(figsize = (12,10))
sb.regplot(df_train['GrLivArea'],df_train['SalePrice'])
plt.show()"""
# Out:
# "plt.figure(figsize = (12,10))\nsb.regplot(df_train['GrLivArea'],df_train['SalePrice'])\nplt.show()"

# %%
"""plt.figure(figsize = (12, 10))
plt.scatter(df_train['OverallQual'],df_train['SalePrice'])
plt.show()"""
# Out:
# "plt.figure(figsize = (12, 10))\nplt.scatter(df_train['OverallQual'],df_train['SalePrice'])\nplt.show()"

# %%
"""plt.figure(figsize = (12, 10))
plt.scatter(df_train['LotArea'],df_train['SalePrice'])
plt.show()"""
# Out:
# "plt.figure(figsize = (12, 10))\nplt.scatter(df_train['LotArea'],df_train['SalePrice'])\nplt.show()"

# %%
"""plt.figure(figsize = (12,10))
plt.scatter(df_train['TotalBsmtSF'],df_train['SalePrice'])
plt.show()"""
# Out:
# "plt.figure(figsize = (12,10))\nplt.scatter(df_train['TotalBsmtSF'],df_train['SalePrice'])\nplt.show()"

# %%
"""plt.figure(figsize = (12,10))
plt.scatter(df_train['1stFlrSF'],df_train['SalePrice'])
plt.show()"""
# Out:
# "plt.figure(figsize = (12,10))\nplt.scatter(df_train['1stFlrSF'],df_train['SalePrice'])\nplt.show()"

# %%
"""plt.figure(figsize = (12,10))
plt.scatter(df_train['TotRmsAbvGrd'],df_train['SalePrice'])
plt.show()"""
# Out:
# "plt.figure(figsize = (12,10))\nplt.scatter(df_train['TotRmsAbvGrd'],df_train['SalePrice'])\nplt.show()"

# %%
"""plt.figure(figsize = (12,10))
plt.scatter(df_train['Fireplaces'],df_train['SalePrice'])
plt.show()"""
# Out:
# "plt.figure(figsize = (12,10))\nplt.scatter(df_train['Fireplaces'],df_train['SalePrice'])\nplt.show()"

# %%
"""plt.figure(figsize = (12,10))
plt.scatter(df_train['FullBath'],df_train['SalePrice'])
plt.show()"""
# Out:
# "plt.figure(figsize = (12,10))\nplt.scatter(df_train['FullBath'],df_train['SalePrice'])\nplt.show()"

# %%
"""plt.figure(figsize = (12,10))
plt.scatter(df_train['GarageCars'],df_train['SalePrice'])
plt.show()"""
# Out:
# "plt.figure(figsize = (12,10))\nplt.scatter(df_train['GarageCars'],df_train['SalePrice'])\nplt.show()"

# %%
"""plt.figure(figsize = (12,10))
plt.scatter(df_train['GarageArea'],df_train['SalePrice'])
plt.show()"""
# Out:
# "plt.figure(figsize = (12,10))\nplt.scatter(df_train['GarageArea'],df_train['SalePrice'])\nplt.show()"

# %%
df_train = df_train.drop(df_train[df_train['GarageArea'] > 1200].index)

# %%
#df_train = df_train.drop(df_train[(df_train['GarageCars'] > 3) & (df_train['SalePrice'] < 650000)].index)

# %%
#df_train = df_train.drop(df_train[(df_train['FullBath'] > 3) & (df_train['SalePrice'] < 600000)].index)

# %%
#df_train = df_train.drop(df_train[(df_train['Fireplaces'] > 2.5) & (df_train['SalePrice'] < 600000)].index)

# %%
#df_train = df_train.drop(df_train[(df_train['TotRmsAbvGrd'] > 12) & (df_train['SalePrice'] < 600000)].index)

# %%
df_train = df_train.drop(df_train[df_train['1stFlrSF'] > 4000].index)

# %%
df_train = df_train.drop(df_train[df_train['TotalBsmtSF'] > 4000].index)

# %%
df_train = df_train.drop(df_train[df_train.GrLivArea >= 4000].index)

# %%
#df_train = df_train.drop(df_train[(df_train['LotArea'] > 50000) & (df_train['SalePrice'] < 500000)].index)

# %%
df_train['SalePrice']
# Out:
# 0       208500
# 1       181500
# 2       223500
# 3       140000
# 4       250000
#          ...
# 1455    175000
# 1456    210000
# 1457    266500
# 1458    142125
# 1459    147500
# Name: SalePrice, Length: 1452, dtype: int64

# %%
'''df_train.drop(['YrSold', 'MoSold', 'MiscVal',  'BsmtHalfBath', 'LowQualFinSF'], 
       axis=1, inplace=True)
df_test.drop(['YrSold', 'MoSold', 'MiscVal', 'BsmtHalfBath', 'LowQualFinSF'], 
       axis=1, inplace=True)'''
# Out:
# "df_train.drop(['YrSold', 'MoSold', 'MiscVal',  'BsmtHalfBath', 'LowQualFinSF'], \n       axis=1, inplace=True)\ndf_test.drop(['YrSold', 'MoSold', 'MiscVal', 'BsmtHalfBath', 'LowQualFinSF'], \n       axis=1, inplace=True)"

# %%
df=pd.concat((df_train,df_test)).reset_index(drop = True)
# Out:
# G:\anaconda\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.

# %%
df_train['SalePrice']
# Out:
# 0       208500
# 1       181500
# 2       223500
# 3       140000
# 4       250000
#          ...
# 1455    175000
# 1456    210000
# 1457    266500
# 1458    142125
# 1459    147500
# Name: SalePrice, Length: 1452, dtype: int64

# %%
df_corr=df.corr()

# %%
plt.figure(figsize=(16,14))
sb.heatmap(df_corr,annot=True)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
df['Total_sqr_footage']=(df['BsmtFinSF1']+df['BsmtFinSF2']+df['1stFlrSF']+df['2ndFlrSF'])
df['YearbltAndRemod']=(df['YearBuilt']+df['YearRemodAdd'])
df['Total_Bathroom']=(df['FullBath']+(0.5*df['HalfBath'])+df['BsmtFullBath']+(0.5*df['BsmtHalfBath']))
df['TotalSF']=(df['TotalBsmtSF']+df['1stFlrSF']+df['2ndFlrSF'])
df['Total_porch']=(df['OpenPorchSF']+df['3SsnPorch']+df['EnclosedPorch']+df['ScreenPorch']+df['WoodDeckSF'])

# %%
#df=df.drop(['GarageCars','1stFlrSF','2ndFlrSF','TotRmsAbvGrd','GarageYrBlt'],axis=1)

# %%
df.shape
# Out:
# (2911, 86)

# %%
df['BsmtExposure']
# Out:
# 0       No
# 1       Gd
# 2       Mn
# 3       No
# 4       Av
#         ..
# 2906    No
# 2907    No
# 2908    No
# 2909    Av
# 2910    Av
# Name: BsmtExposure, Length: 2911, dtype: object

# %%
df['BsmtExposure'].fillna(df['BsmtExposure'].mode()[0],inplace=True)
df['BsmtFullBath'].fillna(df['BsmtFullBath'].mean(),inplace=True)
df['BsmtHalfBath'].fillna(df['BsmtHalfBath'].mean(),inplace=True)
df['KitchenQual'].fillna(df['KitchenQual'].mode()[0],inplace=True)
df['Functional'].fillna(df['Functional'].mode()[0],inplace=True)
df['GarageYrBlt'].fillna(df['GarageYrBlt'].mean(),inplace=True)
df['SaleType'].fillna(df['SaleType'].mode()[0],inplace=True)
df['BsmtCond'].fillna(df['BsmtCond'].mode()[0],inplace=True)
df['BsmtFinType1'].fillna(df['BsmtFinType1'].mode()[0],inplace=True)
df['BsmtFinSF1'].fillna(df['BsmtFinSF1'].mean(),inplace=True)
df['BsmtFinType2'].fillna(df['BsmtFinType2'].mode()[0],inplace=True)
df['BsmtFinSF2'].fillna(df['BsmtFinSF2'].mean(),inplace=True)
df['BsmtUnfSF'].fillna(df['BsmtUnfSF'].mean(),inplace=True)
df['TotalBsmtSF'].fillna(df['TotalBsmtSF'].mean(),inplace=True)
df['GarageFinish'].fillna(df['GarageFinish'].mode()[0],inplace=True)
df['GarageType'].fillna(df['GarageType'].mode()[0],inplace=True)
df['GarageQual'].fillna(df['GarageQual'].mode()[0],inplace=True)
df['MSZoning'].fillna(df['MSZoning'].mode()[0],inplace=True)
df['LotFrontage']=df.groupby('Neighborhood')['LotFrontage'].transform(lambda x: x.fillna(x.median()))
df['Utilities'].fillna(df['Utilities'].mode()[0],inplace=True)
df['Exterior1st'].fillna(df['Exterior1st'].mode()[0],inplace=True)
df['Exterior2nd'].fillna(df['Exterior2nd'].mode()[0],inplace=True)
df['MasVnrType'].fillna(df['MasVnrType'].mode()[0],inplace=True)
df['MasVnrArea'].fillna(df['MasVnrArea'].mean(),inplace=True)
df['BsmtQual'].fillna(df['BsmtQual'].mode()[0],inplace=True)
df['GarageCond'].fillna(df['GarageCond'].mode()[0],inplace=True)
df['GarageArea'].fillna(df['GarageArea'].mean(),inplace=True)
df['GarageCars'].fillna(df['GarageCars'].mean(),inplace=True)
df['FireplaceQu'].fillna(df['FireplaceQu'].mode()[0],inplace=True)
df['Electrical'].fillna(df['Electrical'].mode()[0],inplace=True)

# %%
df['SaleCondition'].unique()
# Out:
# array(['Normal', 'Abnorml', 'Partial', 'AdjLand', 'Alloca', 'Family'],
#       dtype=object)

# %%
df['YearBuilt'].unique()
# Out:
# array([2003, 1976, 2001, 1915, 2000, 1993, 2004, 1973, 1931, 1939, 1965,
#        2005, 1962, 2006, 1960, 1929, 1970, 1967, 1958, 1930, 2002, 1968,
#        2007, 1951, 1957, 1927, 1920, 1966, 1959, 1994, 1954, 1953, 1955,
#        1983, 1975, 1997, 1934, 1963, 1981, 1964, 1999, 1972, 1921, 1945,
#        1982, 1998, 1956, 1948, 1910, 1995, 1991, 2009, 1950, 1961, 1977,
#        1985, 1979, 1885, 1919, 1990, 1969, 1935, 1988, 1971, 1952, 1936,
#        1923, 1924, 1984, 1926, 1940, 1941, 1987, 1986, 2008, 1908, 1892,
#        1916, 1932, 1918, 1912, 1947, 1925, 1900, 1980, 1989, 1992, 1949,
#        1880, 1928, 1978, 1922, 1996, 2010, 1946, 1913, 1937, 1942, 1938,
#        1974, 1893, 1914, 1906, 1890, 1898, 1904, 1882, 1875, 1911, 1917,
#        1872, 1905, 1907, 1896, 1902, 1895, 1879, 1901], dtype=int64)

# %%
df['haspool']=df['PoolArea'].apply(lambda x:1 if x>0 else 0)
df['has2ndfloor']=df['2ndFlrSF'].apply(lambda x:1 if x>0 else 0)
df['hasgarage']=df['GarageArea'].apply(lambda x:1 if x>0 else 0)
df['hasbsmt']=df['TotalBsmtSF'].apply(lambda x:1 if x>0 else 0)
df['hasfireplace']=df['Fireplaces'].apply(lambda x:1 if x>0 else 0)
df['Was_Completed'] = df['SaleCondition'].apply(lambda x: 1 if x != 'Partial' else 0)
df['New_Building']=df['YearBuilt'].apply(lambda x: 1 if x >= 2000 else 0 )

# %%
df.New_Building.unique()
# Out:
# array([1, 0], dtype=int64)

# %%
df['Alley']=df['Alley'].str[0]

# %%
df['Alley'].value_counts()
# Out:
# G    120
# P     78
# Name: Alley, dtype: int64

# %%
df['Alley']=df['Alley'].replace(0,np.nan)

# %%
df['Alley']=df['Alley'].replace(np.nan,'null')

# %%
df['Alley']=df['Alley'].replace({'nan':1,'G':2,'P':3})

# %%
df.Fence.unique()
# Out:
# array([0, 'MnPrv', 'GdWo', 'GdPrv', 'MnWw', nan], dtype=object)

# %%
df['Fence']=df['Fence'].replace(0,np.nan)
df['Fence']=df['Fence'].replace(np.nan,'null')

# %%
df['Fence']=df['Fence'].replace({'null':1,'MnPrv':2,'GdWo':3,'GdPrv':4,'MnWw':5})

# %%
df.MiscFeature.unique()
# Out:
# array([0, 'Shed', 'Gar2', 'Othr', 'TenC', nan], dtype=object)

# %%
df['MiscFeature']=df['MiscFeature'].replace(0,np.nan)
df['MiscFeature']=df['MiscFeature'].replace(np.nan,'null')

# %%
df['MiscFeature']=df['MiscFeature'].replace({'null':1,'Shed':2,'Gar2':3,'Othr':4,'TenC':5})

# %%
df.PoolQC.unique()
# Out:
# array([0, 'Ex', 'Fa', 'Gd', nan], dtype=object)

# %%
df['PoolQC']=df['PoolQC'].replace({'null':1,'Ex':2,'Fa':3,'Gd':4},inplace=True)

# %%
df['PoolQC']=df['PoolQC'].replace(0,np.nan)
df['PoolQC']=df['PoolQC'].replace(np.nan,'null')

# %%
df.isnull().sum().head(50)
# Out:
# 1stFlrSF         0
# 2ndFlrSF         0
# 3SsnPorch        0
# Alley            0
# BedroomAbvGr     0
# BldgType         0
# BsmtCond         0
# BsmtExposure     0
# BsmtFinSF1       0
# BsmtFinSF2       0
# BsmtFinType1     0
# BsmtFinType2     0
# BsmtFullBath     0
# BsmtHalfBath     0
# BsmtQual         0
# BsmtUnfSF        0
# CentralAir       0
# Condition1       0
# Condition2       0
# Electrical       0
# EnclosedPorch    0
# ExterCond        0
# ExterQual        0
# Exterior1st      0
# Exterior2nd      0
# Fence            0
# FireplaceQu      0
# Fireplaces       0
# Foundation       0
# FullBath         0
# Functional       0
# GarageArea       0
# GarageCars       0
# GarageCond       0
# GarageFinish     0
# GarageQual       0
# GarageType       0
# GarageYrBlt      0
# GrLivArea        0
# HalfBath         0
# Heating          0
# HeatingQC        0
# HouseStyle       0
# Id               0
# KitchenAbvGr     0
# KitchenQual      0
# LandContour      0
# ...

# %%
df['Electrical'].value_counts()
# Out:
# SBrkr    2663
# FuseA     188
# FuseF      50
# FuseP       8
# Mix         1
# 0           1
# Name: Electrical, dtype: int64

# %%
df.drop(columns=['PoolQC'],axis=1,inplace=True)
df.drop(columns=['Fence'],axis=1,inplace=True)
df.drop(columns=['MiscFeature'],axis=1,inplace=True)
df.drop(columns=['Alley'],axis=1,inplace=True)

#df.drop(columns=['SalePrice'],axis=1,inplace=True)

# %%
df.isnull().sum().head(60)
# Out:
# 1stFlrSF         0
# 2ndFlrSF         0
# 3SsnPorch        0
# BedroomAbvGr     0
# BldgType         0
# BsmtCond         0
# BsmtExposure     0
# BsmtFinSF1       0
# BsmtFinSF2       0
# BsmtFinType1     0
# BsmtFinType2     0
# BsmtFullBath     0
# BsmtHalfBath     0
# BsmtQual         0
# BsmtUnfSF        0
# CentralAir       0
# Condition1       0
# Condition2       0
# Electrical       0
# EnclosedPorch    0
# ExterCond        0
# ExterQual        0
# Exterior1st      0
# Exterior2nd      0
# FireplaceQu      0
# Fireplaces       0
# Foundation       0
# FullBath         0
# Functional       0
# GarageArea       0
# GarageCars       0
# GarageCond       0
# GarageFinish     0
# GarageQual       0
# GarageType       0
# GarageYrBlt      0
# GrLivArea        0
# HalfBath         0
# Heating          0
# HeatingQC        0
# HouseStyle       0
# Id               0
# KitchenAbvGr     0
# KitchenQual      0
# LandContour      0
# LandSlope        0
# LotArea          0
# ...

# %%
cor=df.corr()

# %%
df.select_dtypes(exclude='object').columns
# Out:
# Index(['1stFlrSF', '2ndFlrSF', '3SsnPorch', 'BedroomAbvGr', 'BsmtFinSF1',
#        'BsmtFinSF2', 'BsmtFullBath', 'BsmtHalfBath', 'BsmtUnfSF',
#        'EnclosedPorch', 'Fireplaces', 'FullBath', 'GarageArea', 'GarageCars',
#        'GarageYrBlt', 'GrLivArea', 'HalfBath', 'Id', 'KitchenAbvGr', 'LotArea',
#        'LotFrontage', 'LowQualFinSF', 'MSSubClass', 'MasVnrArea', 'MiscVal',
#        'MoSold', 'OpenPorchSF', 'OverallCond', 'OverallQual', 'PoolArea',
#        'SalePrice', 'ScreenPorch', 'TotRmsAbvGrd', 'TotalBsmtSF', 'WoodDeckSF',
#        'YearBuilt', 'YearRemodAdd', 'YrSold', 'Total_sqr_footage',
#        'YearbltAndRemod', 'Total_Bathroom', 'TotalSF', 'Total_porch',
#        'haspool', 'has2ndfloor', 'hasgarage', 'hasbsmt', 'hasfireplace',
#        'Was_Completed', 'New_Building'],
#       dtype='object')

# %%
import calendar
df['MoSold']=df['MoSold'].apply(lambda x: calendar.month_abbr[x])

# %%
df['MoSold'].unique()
# Out:
# array(['Feb', 'May', 'Sep', 'Dec', 'Oct', 'Aug', 'Nov', 'Apr', 'Jan',
#        'Jul', 'Mar', 'Jun'], dtype=object)

# %%
"""from pandas.api.types import CategoricalDtype
df['BsmtCond'] = df['BsmtCond'].astype(CategoricalDtype(categories=['NA', 'Po', 'Fa', 'TA', 'Gd', 'Ex'], ordered = True)).cat.codes"""
# Out:
# "from pandas.api.types import CategoricalDtype\ndf['BsmtCond'] = df['BsmtCond'].astype(CategoricalDtype(categories=['NA', 'Po', 'Fa', 'TA', 'Gd', 'Ex'], ordered = True)).cat.codes"

# %%
"""df['BsmtExposure'] = df['BsmtExposure'].astype(CategoricalDtype(categories=['NA', 'Mn', 'Av', 'Gd'], ordered = True)).cat.codes
"""
# Out:
# "df['BsmtExposure'] = df['BsmtExposure'].astype(CategoricalDtype(categories=['NA', 'Mn', 'Av', 'Gd'], ordered = True)).cat.codes\n"

# %%
df['FullBath']
# Out:
# 0       2
# 1       2
# 2       2
# 3       1
# 4       2
#        ..
# 2906    1
# 2907    1
# 2908    1
# 2909    1
# 2910    2
# Name: FullBath, Length: 2911, dtype: int64

# %%
'''df['BsmtFinType1'] = df['BsmtFinType1'].astype(CategoricalDtype(categories=['NA', 'Unf', 'LwQ', 'Rec', 'BLQ','ALQ', 'GLQ'], ordered = True)).cat.codes
df['BsmtFinType2'] = df['BsmtFinType2'].astype(CategoricalDtype(categories=['NA', 'Unf', 'LwQ', 'Rec', 'BLQ','ALQ', 'GLQ'], ordered = True)).cat.codes
df['BsmtQual'] = df['BsmtQual'].astype(CategoricalDtype(categories=['NA', 'Po', 'Fa', 'TA', 'Gd', 'Ex'], ordered = True)).cat.codes
df['ExterQual'] = df['ExterQual'].astype(CategoricalDtype(categories=['Po', 'Fa', 'TA', 'Gd', 'Ex'], ordered = True)).cat.codes
df['ExterCond'] = df['ExterCond'].astype(CategoricalDtype(categories=['Po', 'Fa', 'TA', 'Gd', 'Ex'], ordered = True)).cat.codes
df['Functional'] = df['Functional'].astype(CategoricalDtype(categories=['Sal', 'Sev', 'Maj2', 'Maj1', 'Mod','Min2','Min1', 'Typ'], ordered = True)).cat.codes
df['GarageCond'] = df['GarageCond'].astype(CategoricalDtype(categories=['NA', 'Po', 'Fa', 'TA', 'Gd', 'Ex'], ordered = True)).cat.codes
df['GarageQual'] = df['GarageQual'].astype(CategoricalDtype(categories=['NA', 'Po', 'Fa', 'TA', 'Gd', 'Ex'], ordered = True)).cat.codes
df['GarageFinish'] = df['GarageFinish'].astype(CategoricalDtype(categories=['NA', 'Unf', 'RFn', 'Fin'], ordered = True)).cat.codes
df['HeatingQC'] = df['HeatingQC'].astype(CategoricalDtype(categories=['Po', 'Fa', 'TA', 'Gd', 'Ex'], ordered = True)).cat.codes
df['KitchenQual'] = df['KitchenQual'].astype(CategoricalDtype(categories=['Po', 'Fa', 'TA', 'Gd', 'Ex'], ordered = True)).cat.codes
df['PavedDrive'] = df['PavedDrive'].astype(CategoricalDtype(categories=['N', 'P', 'Y'], ordered = True)).cat.codes
df['Utilities'] = df['Utilities'].astype(CategoricalDtype(categories=['ELO', 'NASeWa', 'NASeWr', 'AllPub'], ordered = True)).cat.codes'''
# Out:
# "df['BsmtFinType1'] = df['BsmtFinType1'].astype(CategoricalDtype(categories=['NA', 'Unf', 'LwQ', 'Rec', 'BLQ','ALQ', 'GLQ'], ordered = True)).cat.codes\ndf['BsmtFinType2'] = df['BsmtFinType2'].astype(CategoricalDtype(categories=['NA', 'Unf', 'LwQ', 'Rec', 'BLQ','ALQ', 'GLQ'], ordered = True)).cat.codes\ndf['BsmtQual'] = df['BsmtQual'].astype(CategoricalDtype(categories=['NA', 'Po', 'Fa', 'TA', 'Gd', 'Ex'], ordered = True)).cat.codes\ndf['ExterQual'] = df['ExterQual'].astype(CategoricalDtype(categories=['Po', 'Fa', 'TA', 'Gd', 'Ex'], ordered = True)).cat.codes\ndf['ExterCond'] = df['ExterCond'].astype(CategoricalDtype(categories=['Po', 'Fa', 'TA', 'Gd', 'Ex'], ordered = True)).cat.codes\ndf['Functional'] = df['Functional'].astype(CategoricalDtype(categories=['Sal', 'Sev', 'Maj2', 'Maj1', 'Mod','Min2','Min1', 'Typ'], ordered = True)).cat.codes\ndf['GarageCond'] = df['GarageCond'].astype(CategoricalDtype(categories=['NA', 'Po', 'Fa', 'TA', 'Gd', 'Ex'], ordered = True)).cat.codes\ndf['Ga
# ...

# %%
col=df.select_dtypes(include='object').columns

# %%
df['Total_sqr_footage'].fillna(df['Total_sqr_footage'].mean(),inplace=True)
df['Total_Bathroom'].fillna(df['Total_Bathroom'].mode()[0],inplace=True)
df['TotalSF'].fillna(df['TotalSF'].mode()[0],inplace=True)

# %%
df.isnull().sum().tail(60)
# Out:
# GarageArea              0
# GarageCars              0
# GarageCond              0
# GarageFinish            0
# GarageQual              0
# GarageType              0
# GarageYrBlt             0
# GrLivArea               0
# HalfBath                0
# Heating                 0
# HeatingQC               0
# HouseStyle              0
# Id                      0
# KitchenAbvGr            0
# KitchenQual             0
# LandContour             0
# LandSlope               0
# LotArea                 0
# LotConfig               0
# LotFrontage             0
# LotShape                0
# LowQualFinSF            0
# MSSubClass              0
# MSZoning                0
# MasVnrArea              0
# MasVnrType              0
# MiscVal                 0
# MoSold                  0
# Neighborhood            0
# OpenPorchSF             0
# OverallCond             0
# OverallQual             0
# PavedDrive              0
# PoolArea                0
# RoofMatl                0
# ...

# %%
df.shape
# Out:
# (2911, 89)

# %%
dummy=pd.get_dummies(df[col],prefix=col)

# %%
dummy.shape
# Out:
# (2911, 262)

# %%
df.drop(col,axis=1,inplace=True)

# %%
df_final=pd.concat([df,dummy],axis=1)

# %%
sum(df_final.isna().any())
# Out:
# 1

# %%
"""final_corr=df_final.corr()
plt.figure(figsize=(18,16))
sb.heatmap(final_corr,annot=True)"""
# Out:
# 'final_corr=df_final.corr()\nplt.figure(figsize=(18,16))\nsb.heatmap(final_corr,annot=True)'

# %%
#df_final=df_final.drop(['GarageCars','1stFlrSF','2ndFlrSF','TotRmsAbvGrd','GarageYrBlt'],axis=1)

# %%
df_final.shape
# Out:
# (2911, 311)

# %%
final_corr=df_final.corr()

# %%
"""plt.figure(figsize=(18,16))
sb.heatmap(final_corr,annot=True)
plt.show()"""
# Out:
# 'plt.figure(figsize=(18,16))\nsb.heatmap(final_corr,annot=True)\nplt.show()'

# %%
X_train=df_final.iloc[0:1452]
X_test=df_final.iloc[1452:]

# %%
X_train.shape,X_test.shape
# Out:
# ((1452, 311), (1459, 311))

# %%
y=X_train['SalePrice']

# %%
X_test.drop(columns=['SalePrice'],axis=1,inplace=True)
# Out:
# G:\anaconda\lib\site-packages\pandas\core\frame.py:4102: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
X_train.drop(columns=['SalePrice'],axis=1,inplace=True)

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import RobustScaler
from sklearn.preprocessing import PowerTransformer
from sklearn.model_selection import train_test_split

# %%
from sklearn.ensemble import GradientBoostingRegressor
clf_ggr = GradientBoostingRegressor(alpha=0.9, criterion='friedman_mse',
                          init=None, learning_rate=0.05, loss='ls', max_depth=3,
                          max_features='sqrt', max_leaf_nodes=None,
                          min_impurity_decrease=0.0, min_impurity_split=None,
                          min_samples_leaf=9, min_samples_split=8,
                          min_weight_fraction_leaf=0.0, n_estimators=1250,
                          n_iter_no_change=None,
                          random_state=None, subsample=0.8, tol=0.0001,validation_fraction=0.1, verbose=0
                          )

# %%
clf_ggr.fit(X_train,y)
clf_ggr.score(X_train,y)
# Out:
# 0.9856265688621999

# %%
import xgboost

# %%
n_estimators=[100,500,900,1100,1500]
max_depth=[2,3,5,10,15]
booster=['gbtree','gblinear']
learning_rate=[0.05,0.1,0.15,0.20]
min_child_weight=[1,2,3,4]
base_score=[0.25,0.5,0.75,1]
regressor=xgboost.XGBRegressor()

hyper_parameter_grid={
    'n_estimators':n_estimators,
    'max_depth':max_depth,
    'learning_rate':learning_rate,
    'min_child_weight':min_child_weight,
    'booster':booster,
    'base_score':base_score
}

# %%
from sklearn.model_selection import RandomizedSearchCV
random_cv=RandomizedSearchCV(estimator=regressor,
                            param_distributions=hyper_parameter_grid,
                            cv=5,n_iter=50,
                            scoring='neg_mean_absolute_error',n_jobs=4,
                            verbose=5,return_train_score=True,
                            random_state=42)

# %%
"random_cv.best_estimator_"
# Out:
# 'random_cv.best_estimator_'

# %%
'''random_cv.fit(X_train,y)
random_cv.score(X_train,y)'''
# Out:
# 'random_cv.fit(X_train,y)\nrandom_cv.score(X_train,y)'

# %%
"""random_cv.best_estimator_"""
# Out:
# 'random_cv.best_estimator_'

# %%
import xgboost as xgb

# %%
a=xgb.XGBRegressor

# %%
#random_cv.best_estimator_
a(base_score=0.25, booster='gbtree', colsample_bylevel=1,
             colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
             importance_type='gain', interaction_constraints=None,
             learning_rate=0.05, max_delta_step=0, max_depth=2,
             min_child_weight=4, monotone_constraints=None,
             n_estimators=900, n_jobs=0, num_parallel_tree=1,
             objective='reg:squarederror', random_state=0, reg_alpha=0,
             reg_lambda=1, scale_pos_weight=1, subsample=1, tree_method=None,
             validate_parameters=False, verbosity=None)
# Out:
# XGBRegressor(base_score=0.25, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints=None,
#              learning_rate=0.05, max_delta_step=0, max_depth=2,
#              min_child_weight=4, missing=nan, monotone_constraints=None,
#              n_estimators=900, n_jobs=0, num_parallel_tree=1,
#              objective='reg:squarederror', random_state=0, reg_alpha=0,
#              reg_lambda=1, scale_pos_weight=1, subsample=1, tree_method=None,
#              validate_parameters=False, verbosity=None)

# %%
from sklearn.linear_model import Lasso

# %%
#lasso = make_pipeline(RobustScaler(), Lasso(alpha =0.0005, random_state=1)

# %%
import xgboost

# %%
from sklearn.ensemble import GradientBoostingRegressor

# %%
classifier_abc=xgb.XGBRegressor(base_score=0.25, booster='gbtree', colsample_bylevel=1,
             colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
             importance_type='gain', interaction_constraints=None,
             learning_rate=0.05, max_delta_step=0, max_depth=2,
             min_child_weight=4, monotone_constraints=None,
             n_estimators=900, n_jobs=0, num_parallel_tree=1,
             objective='reg:squarederror', random_state=0, reg_alpha=0,
             reg_lambda=1, scale_pos_weight=1, subsample=1, tree_method=None,
             validate_parameters=False, verbosity=None)
classifier_abc.fit(X_train,y)
classifier_abc.score(X_train,y)
# Out:
# 0.9749204427710493

# %%
import xgboost as xgb
classifier=xgb.XGBRegressor(base_score=0.25, booster='gbtree', colsample_bylevel=1,
             colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
             importance_type='gain', interaction_constraints=None,
             learning_rate=0.05, max_delta_step=0, max_depth=2,
             min_child_weight=4, monotone_constraints=None,
             n_estimators=900, n_jobs=0, num_parallel_tree=1,
             objective='reg:squarederror', random_state=0, reg_alpha=0,
             reg_lambda=1, scale_pos_weight=1, subsample=1, tree_method=None,
             validate_parameters=False, verbosity=None)
classifier.fit(X_train,y)
classifier.score(X_train,y)
# Out:
# 0.9749204427710493

# %%
from sklearn.linear_model import ElasticNet, Ridge, Lasso
from xgboost import XGBRegressor

# %%
model_EN = ElasticNet(alpha=0.0025, l1_ratio=0.15, max_iter=10000, random_state=0)
model_EN.fit(X_train, np.log1p(y))
EN_preds = model_EN.predict(X_test)

model_R = Ridge(alpha=30, max_iter=10000, random_state=0)
model_R.fit(X_train, np.log1p(y))
R_preds = model_R.predict(X_test)

model_L = Lasso(alpha=0.0006, max_iter=10000, random_state=0)
model_L.fit(X_train, np.log1p(y))
L_preds = model_L.predict(X_test)

model_XGB = XGBRegressor(n_estimators=1000, learning_rate=0.055, objective="reg:squarederror", n_jobs=-1, random_state=0)
model_XGB.fit(X_train, np.log1p(y))
XGB_preds = model_XGB.predict(X_test)

ensemble_preds = 0.75*EN_preds + 0.05*R_preds + 0.05*L_preds + 0.15*XGB_preds
# Out:
# G:\anaconda\lib\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7.025850782961991, tolerance: 0.02268572809503728
#   positive)
# G:\anaconda\lib\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7.0812931882616645, tolerance: 0.02268572809503728
#   positive)

# %%
model_L = Lasso(alpha=0.0006, max_iter=10000, random_state=0)
model_L.fit(X_train, np.log1p(y))
L_preds = model_L.predict(X_test)
# Out:
# G:\anaconda\lib\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7.401124816283754, tolerance: 0.02268572809503728
#   positive)

# %%
y_pred=np.expm1(L_preds)

# %%
y_pred
# Out:
# array([121455.22533869, 148984.56509337, 177191.71466256, ...,
#        159981.83204518, 120719.89903593, 217897.57487759])

# %%
df_submission=pd.DataFrame({'Id':df_test['Id'],'SalePrice':y_pred})

# %%
df_submission.to_csv('sub1.csv',index=False)
