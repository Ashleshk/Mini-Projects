# %%
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('creditcard.csv')

# %%
data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
data.Class.unique()
# Out:
# array([0, 1], dtype=int64)

# %%
data.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  3.919560e-15  5.688174e-16 -8.769071e-15  2.782312e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean  -1.552563e-15  2.010663e-15 -1.694249e-15 -1.927028e-16 -3.137024e-15
# ...

# %%
sb.barplot(data['Class'],data['Amount'])

# %%
data.hist(figsize=(20,20))
plt.show()

# %%
fraud=data[data['Class']==1]
valid=data[data['Class']==0]

outlier=len(fraud) / float(len(valid))

# %%
outlier,len(fraud),len(valid)
# Out:
# (0.0017304750013189597, 492, 284315)

# %%
corr=data.corr()
corr
plt.figure(figsize=(26,22))
sb.heatmap(corr,annot=True)
plt.show()

# %%
#data.plot()

# %%
min_data=data.min()
max_data=data.max()
X_norm=(data-min_data)/(max_data-data)
X_norm
# Out:
#                 Time          V1        V2        V3        V4        V5  \
# 0       0.000000e+00   14.430274  3.282480  7.429209  0.455652  3.227235
# 1       0.000000e+00   45.602568  3.349086  5.261682  0.373242  3.275703
# 2       5.787338e-06   14.436154  3.050513  6.583848  0.367550  3.207493
# 3       5.787338e-06   16.205194  3.260830  6.603617  0.271717  3.267065
# 4       1.157474e-05   15.291111  3.474669  6.366521  0.369481  3.218966
# ...              ...         ...       ...       ...       ...       ...
# 284802  2.879767e+04    3.105904  6.907050  2.002920  0.190926  2.698264
# 284803  3.455740e+04   17.465381  3.285908  6.854089  0.280720  3.377540
# 284804  4.319700e+04  108.948244  3.238720  3.568338  0.293999  3.617335
# 284805  4.319700e+04   20.838352  3.402489  5.648367  0.393745  3.222472
# 284806           inf   18.697354  3.259967  5.649001  0.297838  3.266791
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %%
#X_norm.plot()

# %%
y=data['Class']
#data.drop(columns=['Class'],axis=1,inplace=True)

# %%
columns=data.columns.to_list()

# %%
data.shape,y.shape
# Out:
# ((284807, 31), (284807,))

# %%
sorted_values=data.sort_values('Class',ascending=False).reset_index()
sorted_values.head(5)
# Out:
#     index      Time        V1        V2         V3         V4        V5  \
# 0   42635   41181.0 -7.334341  4.960892  -8.451410   8.174825 -7.237464
# 1  135718   81372.0 -0.885254  1.790649  -0.945149   3.853433 -1.543510
# 2   10568   17520.0 -5.268053  9.067613 -15.960728  10.296603 -4.708241
# 3  215132  139951.0 -2.921944 -0.228062  -5.877289   2.201884 -1.935440
# 4  144104   85864.0 -3.365265  2.928541  -5.660999   3.891160 -1.840375
#
#          V6         V7        V8  ...       V21       V22       V23       V24  \
# 0 -2.382711 -11.508842  4.635798  ...  2.153755  0.033922 -0.014095  0.625250
# 1  0.188582  -2.988383  1.344059  ...  0.746160  0.550802 -0.034882 -0.567608
# 2 -3.395375 -11.161057  5.499963  ...  2.004110  0.191058  0.622928 -1.209264
# 3  0.631141  -1.245106  1.511348  ...  1.441622  0.895528  1.385511 -2.028024
# 4 -1.800887  -5.558679  2.402322  ...  0.875260 -0.102501 -0.606283 -0.743165
#
#         V25       V26       V27       V28  Amount  Class
# ...

# %%
del sorted_values['index']

# %%
sorted_values
# Out:
#             Time        V1        V2         V3         V4        V5  \
# 0        41181.0 -7.334341  4.960892  -8.451410   8.174825 -7.237464
# 1        81372.0 -0.885254  1.790649  -0.945149   3.853433 -1.543510
# 2        17520.0 -5.268053  9.067613 -15.960728  10.296603 -4.708241
# 3       139951.0 -2.921944 -0.228062  -5.877289   2.201884 -1.935440
# 4        85864.0 -3.365265  2.928541  -5.660999   3.891160 -1.840375
# ...          ...       ...       ...        ...        ...       ...
# 284802   65155.0  1.507824 -0.457180  -0.214364  -0.793170 -0.207350
# 284803   65155.0 -0.503377  0.878358   1.541229   0.143517 -1.010869
# 284804   65155.0  1.074335 -0.085551   0.747311   1.395833 -0.553542
# 284805   65156.0  1.134910  0.224390   0.779909   0.936986 -0.280685
# 284806  172792.0 -0.533413 -0.189733   0.703337  -0.506271 -0.012546
#
#               V6         V7        V8        V9  ...       V21       V22  \
# ...

# %%
sorted_values.to_csv()

# %%
from sklearn.model_selection import train_test_split  
X_train, X_test, y_train, y_test = train_test_split(data, y, test_size = 0.2, random_state = 42)

# %%
from sklearn.ensemble import RandomForestClassifier 
# random forest model creation 
rfc = RandomForestClassifier() 
rfc.fit(X_train, y_train) 
rfc.score(X_train, y_train)
# Out:
# G:\anaconda\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# 0.9999034431301982

# %%
# predictions 
y_pred = rfc.predict(X_test)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56864
#            1       0.97      0.76      0.85        98
#
#     accuracy                           1.00     56962
#    macro avg       0.99      0.88      0.93     56962
# weighted avg       1.00      1.00      1.00     56962
